# %% [markdown]
# # Final Project
# ###Bima Fahimna

# %% [markdown]
# ## Load Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn')

# %%
df = pd.read_csv('/content/drive/MyDrive/Ai Mentorship/Machine Learning/Pertemuan 6/breast-cancer-wisconsin.data', 
                 names=['Sample Code Number','Clump Thickness','Uniformity of Cell Size','Uniformity of Cell Shape','Marginal Adhesion','Single Epithelial Cell Size','Bare Nuclei',
                        'Bland Chromatin','Normal Nucleoli','Mitoses','Class'])
df.set_index('Sample Code Number',inplace=True)
df.head(10)
# Out:
#                     Clump Thickness  Uniformity of Cell Size  \
# Sample Code Number
# 1000025                           5                        1
# 1002945                           5                        4
# 1015425                           3                        1
# 1016277                           6                        8
# 1017023                           4                        1
# 1017122                           8                       10
# 1018099                           1                        1
# 1018561                           2                        1
# 1033078                           2                        1
# 1033078                           4                        2
#
#                     Uniformity of Cell Shape  Marginal Adhesion  \
# Sample Code Number
# 1000025                                    1                  1
# 1002945                                    4                  5
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 1000025 to 897471
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Clump Thickness              699 non-null    int64
#  1   Uniformity of Cell Size      699 non-null    int64
#  2   Uniformity of Cell Shape     699 non-null    int64
#  3   Marginal Adhesion            699 non-null    int64
#  4   Single Epithelial Cell Size  699 non-null    int64
#  5   Bare Nuclei                  699 non-null    object
#  6   Bland Chromatin              699 non-null    int64
#  7   Normal Nucleoli              699 non-null    int64
#  8   Mitoses                      699 non-null    int64
#  9   Class                        699 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 60.1+ KB

# %%
dfstr = df[df['Bare Nuclei']=='?']
dfstr
# Out:
#                     Clump Thickness  Uniformity of Cell Size  \
# Sample Code Number
# 1057013                           8                        4
# 1096800                           6                        6
# 1183246                           1                        1
# 1184840                           1                        1
# 1193683                           1                        1
# 1197510                           5                        1
# 1241232                           3                        1
# 169356                            3                        1
# 432809                            3                        1
# 563649                            8                        8
# 606140                            1                        1
# 61634                             5                        4
# 704168                            4                        6
# 733639                            3                        1
# ...

# %%
df1 = df.replace("?", "1")

# %%
df1['Bare Nuclei']=df1["Bare Nuclei"].astype(int)

# %%
df1
# Out:
#                     Clump Thickness  Uniformity of Cell Size  \
# Sample Code Number
# 1000025                           5                        1
# 1002945                           5                        4
# 1015425                           3                        1
# 1016277                           6                        8
# 1017023                           4                        1
# ...                             ...                      ...
# 776715                            3                        1
# 841769                            2                        1
# 888820                            5                       10
# 897471                            4                        8
# 897471                            4                        8
#
#                     Uniformity of Cell Shape  Marginal Adhesion  \
# Sample Code Number
# 1000025                                    1                  1
# ...

# %%
df1.isna().sum()
# Out:
# Clump Thickness                0
# Uniformity of Cell Size        0
# Uniformity of Cell Shape       0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Bland Chromatin                0
# Normal Nucleoli                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %%
df1.describe()
# Out:
#        Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# count       699.000000               699.000000                699.000000
# mean          4.417740                 3.134478                  3.207439
# std           2.815741                 3.051459                  2.971913
# min           1.000000                 1.000000                  1.000000
# 25%           2.000000                 1.000000                  1.000000
# 50%           4.000000                 1.000000                  1.000000
# 75%           6.000000                 5.000000                  5.000000
# max          10.000000                10.000000                 10.000000
#
#        Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# count         699.000000                   699.000000   699.000000
# mean            2.806867                     3.216023     3.486409
# std             2.855379                     2.214300     3.621929
# ...

# %%
df1['Class'].value_counts() #2 for benign, 4 for malignant
                            #Benign = Jinak & Malignant = Ganas
# Out:
# 2    458
# 4    241
# Name: Class, dtype: int64

# %%
# Label endcoding( B=0, M=1 )
from sklearn.preprocessing import LabelEncoder
labelencoder_Y = LabelEncoder()
df1['Diagnosis']=labelencoder_Y.fit_transform(df1['Class'])
df1['Diagnosis'].value_counts()
# Out:
# 0    458
# 1    241
# Name: Diagnosis, dtype: int64

# %%
new_df = df1.drop(columns=['Class'], axis=1)
new_df
# Out:
#                     Clump Thickness  Uniformity of Cell Size  \
# Sample Code Number
# 1000025                           5                        1
# 1002945                           5                        4
# 1015425                           3                        1
# 1016277                           6                        8
# 1017023                           4                        1
# ...                             ...                      ...
# 776715                            3                        1
# 841769                            2                        1
# 888820                            5                       10
# 897471                            4                        8
# 897471                            4                        8
#
#                     Uniformity of Cell Shape  Marginal Adhesion  \
# Sample Code Number
# 1000025                                    1                  1
# ...

# %% [markdown]
# ##Visualisasi Data

# %%
#Jumlah tiap jenis kanker
sns.countplot(new_df['Diagnosis'], label="count", )
plt.title('Jumlah setiap Jenis Kanker',fontdict = {'fontsize' : 25})
plt.show()

# %%
new_df['Diagnosis'].value_counts()
# Out:
# 0    458
# 1    241
# Name: Diagnosis, dtype: int64

# %%
plt.pie(new_df['Diagnosis'].value_counts(),labels =['Benign','Malignant'], 
        startangle = 90,labeldistance=1.15,wedgeprops = { 'linewidth' : 2.5, 'edgecolor' : 'white' },autopct='%1.1f%%',)
plt.legend(loc = 'upper left')
plt.savefig('pie chart.png')
plt.show()

# %%
# Korelasi tiap fitur
plt.figure(figsize=(15,15))
plt.title('Korelasi Tiap Data',fontdict = {'fontsize' : 25})
sns.heatmap(new_df.iloc[:,1:9].corr(),annot=True,fmt=".0%")
plt.savefig('korelasi.png')
plt.show()

# %%
#Mencari Outliers
plt.figure(figsize=(25,13))
sns.boxplot(data=new_df, orient='h')
plt.title('BoxPlot Breast Cancer Wisconsin Data',fontdict = {'fontsize' : 25})
plt.savefig('boxplot.png')
plt.show()

# %% [markdown]
# ##Random Forest

# %% [markdown]
# ### Split Data

# %%
from sklearn.model_selection import train_test_split

data_vars = new_df.columns.values.tolist()
y = ['Diagnosis']
X = [i for i in data_vars if i not in y]

X_train, X_test, y_train, y_test = train_test_split(new_df[X], new_df[y], test_size=0.2, random_state=50)

# %% [markdown]
# ###Train Model

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
#Model Random Forest Classifier dengan random state dan entropy
rf = RandomForestClassifier(random_state=15, criterion="entropy")
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=15)

# %% [markdown]
# ### Test Model

# %%
#Akurasi Model
print('Akurasi Latihan Random Forest:', rf.score(X_train, y_train))
print('Akurasi Ujian Random Forest:', rf.score(X_test, y_test))
# Out:
# Akurasi Latihan Random Forest: 1.0
# Akurasi Ujian Random Forest: 0.9785714285714285

# %%
#Model Report
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

y_rf_test_pred = rf.predict(X_test)

print('Random Forest Model Report:')
print(classification_report(y_test,y_rf_test_pred))
print('\n')
print('Random Forest Confusion Matrix:\n')
print(confusion_matrix(y_test,y_rf_test_pred))
# Out:
# Random Forest Model Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98        95
#            1       0.96      0.98      0.97        45
#
#     accuracy                           0.98       140
#    macro avg       0.97      0.98      0.98       140
# weighted avg       0.98      0.98      0.98       140
#
#
#
# Random Forest Confusion Matrix:
#
# [[93  2]
#  [ 1 44]]

# %% [markdown]
# ###Confusion Matrix

# %%
#Plot Confusion Matrix
y_pred = rf.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_rf_test_pred)

group_names = ["True Negative", "False Positive", "False Negative", "True Positive"]
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
 
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)

plt.figure(figsize=(10, 8))
plt.title('Random Forest Tree Confusion Matrix',fontdict = {'fontsize' : 25})
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='YlGnBu_r')
plt.savefig('RF_CM.png')
plt.show()

# %% [markdown]
# ###Importance Score

# %%
#Fitur Penting
X_ = np.array(X)
importance_scores = rf.feature_importances_
indices = np.argsort(importance_scores)

plt.figure(figsize=(15, 10))
feature_importances = pd.Series(rf.feature_importances_, index=X)
feature_importances.nlargest(20).sort_values(ascending=True).plot(kind='barh')
plt.title('Feature Importance',fontdict = {'fontsize' : 25})
plt.savefig('FI_CM.png')
plt.show()

# %% [markdown]
# ##Support Vector Machine

# %% [markdown]
# ### Train Model

# %%
from sklearn import svm, datasets
#model SVM dengan kernel rbf
svm_rbf = svm.SVC(kernel='rbf', C=1, gamma='auto')

# %%
svm_rbf.fit(X_train, y_train)
# Out:
# SVC(C=1, gamma='auto')

# %% [markdown]
# ###Test Model

# %%
#Akurasi Model
print('Akurasi Latihan Support Vector Machine:', svm_rbf.score(X_train, y_train))
print('Akurasi Ujian Support Vector Machine:', svm_rbf.score(X_test, y_test))
# Out:
# Akurasi Latihan Support Vector Machine: 0.9964221824686941
# Akurasi Ujian Support Vector Machine: 0.9571428571428572

# %%
#Model Report

y_svm_test_pred = svm_rbf.predict(X_test)

print('SVM Model Report:')
print(classification_report(y_test,y_svm_test_pred))
print('\n')
print('SVM Confusion Matrix:\n')
print(confusion_matrix(y_test,y_svm_test_pred))
# Out:
# SVM Model Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97        95
#            1       0.90      0.98      0.94        45
#
#     accuracy                           0.96       140
#    macro avg       0.94      0.96      0.95       140
# weighted avg       0.96      0.96      0.96       140
#
#
#
# SVM Confusion Matrix:
#
# [[90  5]
#  [ 1 44]]

# %% [markdown]
# ###Confusion Matrix

# %%
#Plot Confusion Matrix
y_pred = svm_rbf.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_svm_test_pred)

group_names = ["True Negative", "False Positive", "False Negative", "True Positive"]
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
 
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)

plt.figure(figsize=(10, 8))
plt.title('SVM Confusion Matrix',fontdict = {'fontsize' : 25})
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='YlGnBu_r')
plt.savefig('SVM_CM.png')
plt.show()
